# %% [markdown]
# <a href="https://colab.research.google.com/github/Mell03y/Mell03y/blob/main/VB_YZ_Ders_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2
# Out:
# 2

# %%
2 + 5
# Out:
# 7

# %%
age=10

# %%
age
# Out:
# 10

# %%
age +5
# Out:
# 15

# %%
age + age
# Out:
# 20

# %%
age=15

# %%
age + 5
# Out:
# 20
