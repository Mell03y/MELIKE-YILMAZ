# %% [markdown]
# <a href="https://colab.research.google.com/github/Mell03y/Mell03y/blob/main/VB__YZ__Ders__2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
3 + 5
# Out:
# 8

# %%
800/7
# Out:
# 114.28571428571429

# %%
5+5+5
# Out:
# 15

# %% [markdown]
# Değişkenler

# %%
age=20

# %%
age
# Out:
# 20

# %%
age +5
# Out:
# 25

# %%
age *15 + 5
# Out:
# 305

# %%
age + age
# Out:
# 40

# %%
age = 30

# %%
age
# Out:
# 30

# %%
age + 10
# Out:
# 40

# %%
yaş = 20

# %%
abi = 30

# %%
age + yaş + abi
# Out:
# 80

# %%
50 / 5 #type
# Out:
# 10.0

# %%
40 * 3
# Out:
# 120

# %%
800/7
# Out:
# 114.28571428571429

# %%
#integer - int

# %%
type(10)
# Out:
# int

# %%
type(10 * 5)
# Out:
# int

# %%
type(age)
# Out:
# int

# %%
x = -100

# %%
type(x)
# Out:
# int

# %%
y = 800 / 7

# %%
y
# Out:
# 114.28571428571429

# %%
type(y) #floating point - float
# Out:
# float

# %%
y + x
# Out:
# 14.285714285714292

# %%
type(y + x)
# Out:
# float

# %%
z = x + y

# %%
z
# Out:
# 14.285714285714292

# %%
type(z)
# Out:
# float

# %%
myFloat = 3.1456

# %%
type(myFloat)
# Out:
# float

# %%
# değişken isimlendirme
#camelCase --küçük harf başlayıp 2. kelime başlığı büyük harf-- myFloat
#snake_case --my_float şeklinde ayırım

# %%
5 * 5 *  5 * 5
# Out:
# 625

# %%
5**4 # üslü ifadeler
# Out:
# 625

# %%
10/4
# Out:
# 2.5

# %%
10 % 4 # kalanı verir
# Out:
# 2

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
print("Merhaba Dünya")
# Out:
# Merhaba Dünya

# %%
name = "melike"

# %%
type(name) #str -strings-- yazı
# Out:
# str

# %%
name2 ='melike'

# %%
name2
# Out:
# 'melike'

# %%
" 'Türkiye'nin başkenti Ankara'dır"
# Out:
# " 'Türkiye'nin başkenti Ankara'dır"

# %%
name # nokta konulduğunda ihtiyaca göre öneriler verir
# Out:
# 'melike'

# %%
name.capitalize()
# Out:
# 'Melike'

# %%
help(name.capitalize) # python dökümantasyon kısmındada öğrenilebilir
# Out:
# Help on built-in function capitalize:
#
# capitalize() method of builtins.str instance
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.

# %%
isim = "melike y"

# %%
isim.capitalize()
# Out:
# 'Melike  y'

# %%
x = "10" # rakam olarak algılamaz o yüzden matematematiksel işlem yapılamaz

# %%
x
# Out:
# '10'

# %%
# x + 5-- iki farklı değişken tipi  matematiksel işleme girdiğinde hata verir. int ve str toplanmaya çalışıldı.

# %%
type(x)
# Out:
# str

# %%
isim
# Out:
# 'melike y'

# %%
isim.upper() #upper bütün harfleri büyütme
# Out:
# 'MELIKE Y'

# %%
isim
# Out:
# 'melike y'

# %%
buyuk_isim = print(isim.upper())
# Out:
# MELIKE Y

# %%
len(isim) #uzunluk - lenght
# Out:
# 8

# %%
name = "kedi"

# %%
len(name)
# Out:
# 4

# %% [markdown]
# ** INDEX **

# %%
myString = "Hello Phyton"

# %%
len(myString)
# Out:
# 12

# %%
myString[1]
# Out:
# 'e'

# %%
myString[6]
# Out:
# 'P'

# %%
myString[8]
# Out:
# 'y'

# %%
myString[9]
# Out:
# 't'

# %%
ad = "Melike Yılmaz"

# %%
len(ad)
# Out:
# 13

# %%
ad[0]
# Out:
# 'M'

# %%
ad[1]
# Out:
# 'e'

# %%
ad[2]
# Out:
# 'l'

# %%
len(ad) - 1
# Out:
# 12

# %%
ad[len(ad)-1]
# Out:
# 'z'

# %%
ad[-1] # son index i verme
# Out:
# 'z'

# %%
barcode = "ABC123456789"

# %%
barcode[0]
# Out:
# 'A'

# %%
barcode[3]
# Out:
# '1'

# %%
barcode[2]
# Out:
# 'C'

# %%
barcode[0] + barcode[3] + barcode[2]
# Out:
# 'A1C'

# %%
barcode[0] + barcode[1] + barcode[2] #toplama yapmaz yan yana yazar
# Out:
# 'ABC'

# %%
#slicing, starting index, stopping index, stopping size

# %%
barcode
# Out:
# 'ABC123456789'

# %%
barcode[::]
# Out:
# 'ABC123456789'

# %%
barcode[3::]
# Out:
# '123456789'

# %%
barcode[5::]
# Out:
# '3456789'

# %%
barcode[5:8:]
# Out:
# '345'

# %%
barcode[1:5:]
# Out:
# 'BC12'

# %%
barcode[0:7:2]
# Out:
# 'AC24'

# %%
barcode = "ABCDE123123982" #tek satırda "DE" yi alın.

# %%
barcode[3:5:]
# Out:
# 'DE'

# %%
barcode.split()
# Out:
# ['ABCDE123123982']

# %%
name = "Melike Yılmaz"

# %%
name.split()
# Out:
# ['Melike', 'Yılmaz']

# %%
type(name.split())
# Out:
# list

# %%
#list-- Listeler --Farklı veri tiplerini tutma

# %%
myList = [10,20,30]

# %%
type(myList)
# Out:
# list

# %%
x = 15
y = 25
z = 35

# %%
myList = [x,y,z]

# %%
myList
# Out:
# [15, 25, 35]

# %%
myList[0]
# Out:
# 15

# %%
len(myList)
# Out:
# 3

# %%
myList.append(30) #her yeni çalıştrmada tekrar ekler

# %%
myList
# Out:
# [15, 25, 35, 50, 50, 40, 30, 30]

# %%
len(myList)
# Out:
# 8

# %%
yaş = input("yaşınızı giriniz:") #girdi ister
# Out:
# yaşınızı giriniz:25

# %%
yaş
# Out:
# '25'

# %%
mixList = ["melike",15 ,25]

# %%
mixList
# Out:
# ['melike', 15, 25]

# %%
mixList[0]
# Out:
# 'melike'

# %%
type(mixList)
# Out:
# list

# %%
list1 = [10,20,30]
list2 = [40,50,60]

# %%
list1 + list2
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
type(mixList[0])
# Out:
# str

# %%
type(mixList[1])
# Out:
# int

# %%
myBestlist = [10,20,3.15,"melike",[1,2,3]]

# %%
myBestlist
# Out:
# [10, 20, 3.15, 'melike', [1, 2, 3]]

# %%
len(myBestlist)
# Out:
# 5

# %%
myBestlist[0]
# Out:
# 10

# %%
myBestlist[3]
# Out:
# 'melike'

# %%
myBestlist[4]
# Out:
# [1, 2, 3]

# %%
type(myBestlist[0])
# Out:
# int

# %%
type(myBestlist[3])
# Out:
# str

# %%
type(myBestlist[4])
# Out:
# list

# %%
myBestlist # 4.indexdeki 3 ü getirme yöntemleri
# Out:
# [10, 20, 3.15, 'melike', [1, 2, 3]]

# %%
myBestlist[4][2]
# Out:
# 3

# %%
mySmallist = myBestlist[4]

# %%
mySmallist
# Out:
# [1, 2, 3]

# %%
mySmallist[2]
# Out:
# 3

# %%
myBestlist[-1][-1]
# Out:
# 3

# %%
fruit_list = ["banana","apple"]

# %%
calori_list = [200,100]

# %%
fruit_list[1]
# Out:
# 'apple'

# %%
calori_list[1]
# Out:
# 100

# %%
fitness_dic = {"banana":200,"apple":100}

# %%
type(fitness_dic)
# Out:
# dict

# %%
fitness_dic["banana"]
# Out:
# 200

# %%
fitness_dic["apple"]
# Out:
# 100
